# %% [markdown]
# # Chapter 6: Precognition (Thinking Step by Step)
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str, system_prompt="", prefill=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt},
          {"role": "assistant", "content": prefill}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (0.86.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Volumes/T9/dev/prompt-eng-interactive-tutorial/venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ---
#
# ## Lesson
#
# If someone woke you up and immediately started asking you several complicated questions that you had to respond to right away, how would you do? Probably not as good as if you were given time to **think through your answer first**.
#
# Guess what? Claude is the same way.
#
# **Giving Claude time to think step by step sometimes makes Claude more accurate**, particularly for complex tasks. However, **thinking only counts when it's out loud**. You cannot ask Claude to think but output only the answer - in this case, no thinking has actually occurred.

# %% [markdown]
# ### Examples
#
# In the prompt below, it's clear to a human reader that the second sentence belies the first. But **Claude takes the word "unrelated" too literally**.

# %%
# Prompt
PROMPT = """Is this movie review sentiment positive or negative?

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since the year 1900."""

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# The sentiment is **negative/sarcastic**.
#
# While the first sentence appears positive on the surface ("blew my mind," "freshness and originality"), the second sentence reveals this is sarcasm. By claiming to have lived under a rock since 1900, the reviewer is implying that the movie is actually *not* fresh or original at all—it's so derivative that only someone completely isolated from modern cinema would find it novel.
#
# The review is using irony to deliver a critical message.

# %% [markdown]
# To improve Claude's response, let's **allow Claude to think things out first before answering**. We do that by literally spelling out the steps that Claude should take in order to process and think through its task. Along with a dash of role prompting, this empowers Claude to understand the review more deeply.

# %%
# System prompt
SYSTEM_PROMPT = "You are a savvy reader of movie reviews."

# Prompt
PROMPT = """Is this review sentiment positive or negative? First, write the best arguments for each side in <positive-argument> and <negative-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))
# Out:
# <positive-argument>
# The reviewer explicitly states the movie "blew my mind" and praises it for "freshness and originality" - these are strong positive descriptors that, taken at face value, indicate genuine enthusiasm for the film.
# </positive-argument>
#
# <negative-argument>
# The phrase "In totally unrelated news, I have been living under a rock since 1900" is sarcasm that undermines the positive statement. The reviewer is implying they're so out of touch with cinema that their judgment is unreliable. This self-deprecating comment suggests the movie is likely NOT actually fresh or original, but rather derivative or conventional - and the reviewer is being ironic about their own inability to recognize this.
# </negative-argument>
#
# **Answer: NEGATIVE**
#
# This is a sarcastic review. The reviewer is using irony to mock the film by praising it while simultaneously admitting they're completely out of touch with modern cinema. The implication is that only someone who hasn't seen a movie in over a century would find this film genuinely fresh and original, suggesting it's actually quite derivative and unoriginal.

# %% [markdown]
# **Claude is sometimes sensitive to ordering**. This example is on the frontier of Claude's ability to understand nuanced text, and when we swap the order of the arguments from the previous example so that negative is first and positive is second, this changes Claude's overall assessment to positive.
#
# In most situations (but not all, confusingly enough), **Claude is more likely to choose the second of two options**, possibly because in its training data from the web, second options were more likely to be correct.

# %%
# Prompt
PROMPT = """Is this review sentiment negative or positive? First write the best arguments for each side in <negative-argument> and <positive-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. Unrelatedly, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# **Letting Claude think can shift Claude's answer from incorrect to correct**. It's that simple in many cases where Claude makes mistakes!
#
# Let's go through an example where Claude's answer is incorrect to see how asking Claude to think can fix that.

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Let's fix this by asking Claude to think step by step, this time in `<brainstorm>` tags.

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956. First brainstorm about some actors and their birth years in <brainstorm> tags, then give your answer."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 6.1 - Classifying Emails](#exercise-61---classifying-emails)
# - [Exercise 6.2 - Email Classification Formatting](#exercise-62---email-classification-formatting)

# %% [markdown]
# ### Exercise 6.1 - Classifying Emails
# In this exercise, we'll be instructing Claude to sort emails into the following categories:
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
# For the first part of the exercise, change the `PROMPT` to **make Claude output the correct classification and ONLY the classification**. Your answer needs to **include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category**.
#
# Refer to the comments beside each email in the `EMAILS` list to know which category that email should be classified under.

# %%
# Prompt template with a placeholder for the variable content
PROMPT = """Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): {email}"""

# Prefill for Claude's response, if any
PREFILL = ""

# Variable content stored as a list
EMAILS = [
    "Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.", # (B) Broken or defective item
    "Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?", # (A) Pre-sale question OR (D) Other (please explain)
    "I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???", # (C) Billing question
    "How did I get here I am not good with computer.  Halp." # (D) Other (please explain)
]

# Correct categorizations stored as a list of lists to accommodate the possibility of multiple correct categorizations per email
ANSWERS = [
    ["B"],
    ["A","D"],
    ["C"],
    ["D"]
]

# Dictionary of string values for each category to be used for regex grading
REGEX_CATEGORIES = {
    "A": "A\) P",
    "B": "B\) B",
    "C": "C\) B",
    "D": "D\) O"
}

# Iterate through list of emails
for i,email in enumerate(EMAILS):
    
    # Substitute the email text into the email placeholder variable
    formatted_prompt = PROMPT.format(email=email)
   
    # Get Claude's response
    response = get_completion(formatted_prompt, prefill=PREFILL)

    # Grade Claude's response
    grade = any([bool(re.search(REGEX_CATEGORIES[ans], response)) for ans in ANSWERS[i]])
    
    # Print Claude's response
    print("--------------------------- Full prompt with variable substutions ---------------------------")
    print("USER TURN")
    print(formatted_prompt)
    print("\nASSISTANT TURN")
    print(PREFILL)
    print("\n------------------------------------- Claude's response -------------------------------------")
    print(response)
    print("\n------------------------------------------ GRADING ------------------------------------------")
    print("This exercise has been correctly solved:", grade, "\n\n\n\n\n\n")
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\)'
# <>:26: SyntaxWarning: invalid escape sequence '\)'
# <>:27: SyntaxWarning: invalid escape sequence '\)'
# <>:28: SyntaxWarning: invalid escape sequence '\)'
# <>:25: SyntaxWarning: invalid escape sequence '\)'
# <>:26: SyntaxWarning: invalid escape sequence '\)'
# <>:27: SyntaxWarning: invalid escape sequence '\)'
# <>:28: SyntaxWarning: invalid escape sequence '\)'
# /var/folders/m5/p028sb7n72l2m83bd51xsl3h0000gq/T/ipykernel_33246/3694550794.py:25: SyntaxWarning: invalid escape sequence '\)'
#   "A": "A\) P",
# /var/folders/m5/p028sb7n72l2m83bd51xsl3h0000gq/T/ipykernel_33246/3694550794.py:26: SyntaxWarning: invalid escape sequence '\)'
#   "B": "B\) B",
# /var/folders/m5/p028sb7n72l2m83bd51xsl3h0000gq/T/ipykernel_33246/3694550794.py:27: SyntaxWarning: invalid escape sequence '\)'
#   "C": "C\) B",
# /var/folders/m5/p028sb7n72l2m83bd51xsl3h0000gq/T/ipykernel_33246/3694550794.py:28: SyntaxWarning: invalid escape sequence '\)'
#   "D": "D\) O"
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# **(B) Broken or defective item**
#
# This email describes a malfunctioning product (strange noise, burning smell) and requests a replacement, which clearly indicates a defective item issue rather than a pre-sale question, billing matter, or other concern.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# **(A) Pre-sale question**
#
# This is a customer asking about the product's capabilities and intended use before making a purchase decision (or before using a recently purchased product). They're seeking clarification on whether the Mixmaster 4000 is suitable for a non-food application.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# **(C) Billing question**
#
# This email is clearly a billing/account issue. The customer is reporting that they cancelled their subscription but are still being charged monthly after 4 months. This falls under billing problems rather than the other categories.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): How did I get here I am not good with computer.  Halp.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# **(D) Other**
#
# **Explanation:** This email does not fit into the pre-sale, defective item, or billing categories. The customer appears to be confused about how they accessed something (possibly the website, support portal, or email system) and is expressing general frustration with their technical ability. This is a general support/navigation issue rather than a specific product or billing concern.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_6_1_hint; print(exercise_6_1_hint)

# %% [markdown]
# Still stuck? Run the cell below for an example solution.

# %%
from hints import exercise_6_1_solution; print(exercise_6_1_solution)

# %% [markdown]
# ### Exercise 6.2 - Email Classification Formatting
# In this exercise, we're going to refine the output of the above prompt to yield an answer formatted exactly how we want it.
#
# Use your favorite output formatting technique to make Claude wrap JUST the letter of the correct classification in `<answer></answer>` tags. For instance, the answer to the first email should contain the exact string `<answer>B</answer>`.
#
# Refer to the comments beside each email in the `EMAILS` list if you forget which letter category is correct for each email.

# %%
# Prompt template with a placeholder for the variable content
PROMPT = """Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): {email}. Wrap response (letters only) in <answer> tags."""

# Prefill for Claude's response, if any
PREFILL = ""

# Variable content stored as a list
EMAILS = [
    "Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.", # (B) Broken or defective item
    "Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?", # (A) Pre-sale question OR (D) Other (please explain)
    "I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???", # (C) Billing question
    "How did I get here I am not good with computer.  Halp." # (D) Other (please explain)
]

# Correct categorizations stored as a list of lists to accommodate the possibility of multiple correct categorizations per email
ANSWERS = [
    ["B"],
    ["A","D"],
    ["C"],
    ["D"]
]

# Dictionary of string values for each category to be used for regex grading
REGEX_CATEGORIES = {
    "A": "<answer>A</answer>",
    "B": "<answer>B</answer>",
    "C": "<answer>C</answer>",
    "D": "<answer>D</answer>"
}

# Iterate through list of emails
for i,email in enumerate(EMAILS):
    
    # Substitute the email text into the email placeholder variable
    formatted_prompt = PROMPT.format(email=email)
   
    # Get Claude's response
    response = get_completion(formatted_prompt, prefill=PREFILL)

    # Grade Claude's response
    grade = any([bool(re.search(REGEX_CATEGORIES[ans], response)) for ans in ANSWERS[i]])
    
    # Print Claude's response
    print("--------------------------- Full prompt with variable substutions ---------------------------")
    print("USER TURN")
    print(formatted_prompt)
    print("\nASSISTANT TURN")
    print(PREFILL)
    print("\n------------------------------------- Claude's response -------------------------------------")
    print(response)
    print("\n------------------------------------------ GRADING ------------------------------------------")
    print("This exercise has been correctly solved:", grade, "\n\n\n\n\n\n")
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.. Wrap response (letters only) in <answer> tags.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# <answer>B</answer>
#
# This email describes a product that is not functioning properly (strange noise, burning smell), which indicates a broken or defective item requiring replacement.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?. Wrap response (letters only) in <answer> tags.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# <answer>A</answer>
#
# This is a pre-sale question. The customer is asking about the capabilities and intended use of the Mixmaster 4000 before making a purchase decision or confirming whether their existing unit can be used for a particular purpose.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???. Wrap response (letters only) in <answer> tags.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# <answer>C</answer>
#
# This is a billing question. The customer is complaining about ongoing monthly charges after cancelling their subscription, which is a billing/account issue.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A) Pre-sale question OR (B) Broken or defective item, (C) Billing question, OR (D) Other (please explain): How did I get here I am not good with computer.  Halp.. Wrap response (letters only) in <answer> tags.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# <answer>D</answer>
#
# This email doesn't fit the pre-sale, defective item, or billing categories. The customer appears to be confused about how they accessed something (possibly the website or support system) and is asking for general technical help navigating a computer interface. This is a general support/navigation issue.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_6_2_hint; print(exercise_6_2_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = """Is this movie review sentiment positive or negative?

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since the year 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %%
# System prompt
SYSTEM_PROMPT = "You are a savvy reader of movie reviews."

# Prompt
PROMPT = """Is this review sentiment positive or negative? First, write the best arguments for each side in <positive-argument> and <negative-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))

# %%
# Prompt
PROMPT = """Is this review sentiment negative or positive? First write the best arguments for each side in <negative-argument> and <positive-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. Unrelatedly, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956. First brainstorm about some actors and their birth years in <brainstorm> tags, then give your answer."

# Print Claude's response
print(get_completion(PROMPT))
